# %% [markdown]
# ## Jupyter (IPython) Has Awesome Shortcuts!!

# %%
# Remember those bash commands??  You can use them here!!
# ! alerts the ipython notebook that this will be a bash command
# !ls data/
# Out:
# nytimes.csv

# %% [markdown]
# ### Need help?  Press ESC then h

# %% [markdown]
# # Playing With NY Times Data

# %%
# Lets import the pandas package, call it pd
import pandas as pd
pd
# Out:
# <module 'pandas' from '/Users/meredithnachman/anaconda/lib/python2.7/site-packages/pandas/__init__.pyc'>

# %%
# Using shortcuts, go to the end of read_ and press tab...
 pd.read_csv()
# Out:
#   File "<ipython-input-3-da3f62edb60b>", line 2
#     pd.read_csv()
#     ^
# IndentationError: unexpected indent

# %%
# Using shortcuts, now place the cursor between the (), hold shift and tap tab (try tapping again)
pd.read_csv()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-b6029cbe7cd7> in <module>()
#       1 # Using shortcuts, now place the cursor between the (), hold shift and tap tab (try tapping again)
# ----> 2 pd.read_csv()
#
# TypeError: parser_f() takes at least 1 argument (0 given)

# %%
# Now lets do something fun!!!
df = pd.read_csv('data/nytimes.csv')
df.head(120000)
# Out:
#         Age  Gender  Impressions  Clicks  Signed_In
# 0        36       0            3       0          1
# 1        73       1            3       0          1
# 2        30       0            3       0          1
# 3        49       1            3       0          1
# 4        47       1           11       0          1
# 5        47       0           11       1          1
# 6         0       0            7       1          0
# 7        46       0            5       0          1
# 8        16       0            3       0          1
# 9        52       0            4       0          1
# 10        0       0            8       1          0
# 11       21       0            3       0          1
# 12        0       0            4       0          0
# 13       57       0            6       0          1
# 14       31       0            5       0          1
# 15        0       0            6       0          0
# 16       40       1            3       0          1
# 17       31       1            5       0          1
# 18       38       0            4       0          1
# 19        0       0            5       0          0
# 20       59       1            4       0          1
# 21       61       0            6       0          1
# 22       48       0            7       0          1
# 23       29       1            2       0          1
# 24        0       0            4       0          0
# 25       19       1            4       0          1
# 26       19       0            3       0          1
# 27       48       1            9       0          1
# 28       48       1            4       0          1
# 29       21       1            5       0          1
# ...     ...     ...          ...     ...        ...
# 119970   37       0            3       0          1
# 119971    0       0            4       1          0
# 119972   17       1            5       0          1
# 119973   17       1            2       0          1
# 119974   38       1            7       0          1
# 119975   47       1            9       1          1
# 119976   50       1            6       0          1
# 119977   24       1            1       0          1
# 119978   32       0            5       0          1
# 119979   27       1            4       0          1
# 119980   57       1            4       0          1
# 119981   28       0            2       0          1
# 119982    0       0            6       1          0
# 119983   40       1            2       0          1
# 119984   45       1            4       0          1
# 119985    0       0            4       1          0
# 119986    0       0            2       1          0
# 119987   57       0            5       0          1
# 119988    0       0            4       0          0
# 119989    0       0            7       0          0
# 119990    0       0            5       0          0
# 119991   48       1            4       0          1
# 119992   42       0            6       0          1
# 119993   39       1            9       0          1
# 119994    0       0            7       1          0
# 119995   34       1            7       0          1
# 119996   40       0            4       0          1
# 119997    0       0            8       0          0
# 119998   60       0            7       0          1
# 119999   42       1            6       0          1
#
# [120000 rows x 5 columns]

# %% [markdown]
# ## Pandas is built around DataFrames
# ### You just created your first one!
#
#     - A DataFrame is made up of Series, which you mght call a column
#     - We will call it a feature

# %%
# This is a Series
df.Age

# but I only want to see the first 5 records
df.Age.head()
# Out:
# 0    36
# 1    73
# 2    30
# 3    49
# 4    47
# Name: Age, dtype: int64

# %%
# Lets aggregate this Series
df.Age.sum()
# Out:
# 13516010

# %%
# Wow, thats really old?  Always be careful to understand what the data is saying
df.Age.mean()
# Out:
# 29.48255064446679

# %% [markdown]
# ### You can manipulate Series easily

# %%
df['impressions_squared'] = df.Impressions * df.Impressions

# %%
df.Impressions.head(1) * df.Impressions.head(1)
# Out:
# 0    9
# Name: Impressions, dtype: int64

# %%
df['clicks_per_impression'] = df.Clicks / df.Impressions

# %%
# Well that wasn't extremely helpful...
# how would we get clicks per impression??
df.head(20)
# Out:
#     Age  Gender  Impressions  Clicks  Signed_In  impressions_squared  \
# 0    36       0            3       0          1                    9
# 1    73       1            3       0          1                    9
# 2    30       0            3       0          1                    9
# 3    49       1            3       0          1                    9
# 4    47       1           11       0          1                  121
# 5    47       0           11       1          1                  121
# 6     0       0            7       1          0                   49
# 7    46       0            5       0          1                   25
# 8    16       0            3       0          1                    9
# 9    52       0            4       0          1                   16
# 10    0       0            8       1          0                   64
# 11   21       0            3       0          1                    9
# 12    0       0            4       0          0                   16
# 13   57       0            6       0          1                   36
# 14   31       0            5       0          1                   25
# 15    0       0            6       0          0                   36
# 16   40       1            3       0          1                    9
# 17   31       1            5       0          1                   25
# 18   38       0            4       0          1                   16
# 19    0       0            5       0          0                   25
#
#     clicks_per_impression
# 0                0.000000
# 1                0.000000
# 2                0.000000
# 3                0.000000
# 4                0.000000
# 5                0.090909
# 6                0.142857
# 7                0.000000
# 8                0.000000
# 9                0.000000
# 10               0.125000
# 11               0.000000
# 12               0.000000
# 13               0.000000
# 14               0.000000
# 15               0.000000
# 16               0.000000
# 17               0.000000
# 18               0.000000
# 19               0.000000

# %% [markdown]
# ### Lets Group and Plot the Data

# %%
# This is a magic command, now plot will be done in the notebook
# %matplotlib inline

# %%
# We can group data and aggregate it
grouped_df = df.groupby('Age').sum()

# %%
# Cool!  Look how many infants are reading the news!! 
grouped_df.head(30)
# Out:
#      Gender  Impressions  Clicks  Signed_In  impressions_squared  \
# Age
# 0         0       685483   19480          0              4115525
# 7         1           26       3          5                  152
# 8        12           94       4         15                  710
# 9        32          265       5         48                 1689
# 10       81          544      19        113                 3162
# 11      190         1442      36        283                 8868
# 12      386         2863      92        586                16935
# 13      729         5290     158       1059                32206
# 14     1186         8651     230       1718                52503
# 15     1755        12880     392       2605                76304
# 16     2393        17181     522       3443               103797
# 17     2705        20003     604       3953               121733
# 18     2892        27001     458       5424               161213
# 19     3499        32649     312       6509               196127
# 20     3374        31495     294       6337               188593
# 21     3394        32285     314       6384               195773
# 22     3390        31969     314       6394               192437
# 23     3473        32559     329       6488               196153
# 24     1699        15627     146       3158                93289
# 25     1744        16367     146       3260                99029
# 26     3381        32130     322       6405               192420
# 27     3451        32640     333       6551               194306
# 28     3381        31483     305       6359               187673
# 29     3436        31572     303       6379               187372
# 30     3531        33121     370       6617               198973
# 31     3471        32225     342       6439               193419
# 32     3400        32304     340       6443               193684
# 33     3417        32220     317       6431               193208
# 34     1746        16449     159       3290                99157
# 35     2083        19788     198       3932               118070
#
#      clicks_per_impression
# Age
# 0              3861.286179
# 7                 0.809524
# 8                 0.715909
# 9                 0.739683
# 10                4.285714
# 11                6.885354
# 12               19.247222
# 13               34.250938
# 14               46.672378
# 15               81.156469
# 16              103.210845
# 17              117.792735
# 18               93.376985
# 19               61.571606
# 20               58.611855
# 21               61.836039
# 22               60.971956
# 23               67.764272
# 24               29.597208
# 25               26.592569
# 26               63.075144
# 27               65.066822
# 28               63.242927
# 29               59.834776
# 30               72.851454
# 31               68.545008
# 32               70.278630
# 33               61.695646
# 34               35.284968
# 35               37.564008

# %%
# Oops, thats no too pretty
grouped_df.plot(y='Clicks')

# %%
# This is how you filter data, lets remove those 0yr olds
# NOTE: Dont worry if this logic is confusing, Pandas hacked Python for thise filter!
grouped_df[grouped_df.index!=0].head()
# Out:
#      Gender  Impressions  Clicks  Signed_In  impressions_squared  \
# Age
# 7         1           26       3          5                  152
# 8        12           94       4         15                  710
# 9        32          265       5         48                 1689
# 10       81          544      19        113                 3162
# 11      190         1442      36        283                 8868
#
#      clicks_per_impression
# Age
# 7                 0.809524
# 8                 0.715909
# 9                 0.739683
# 10                4.285714
# 11                6.885354

# %%
# However filtering is not done in place
# so you don't save the new dataset before you get the right filter
grouped_df = grouped_df[grouped_df.index!=0]

# %%
df_nozeros = df[df.index!=0]

# %%
df_nozeros.Age.plot(y='Clicks')

# %%
grouped_df.plot(y='Clicks')

# %% [markdown]
# ## Try Playing with the data yourself!
#     - What is the avergage age by gender?
#     - Can you find the converison rate by Age range?
#         - A converison is an impresison that caused a click
#         - Can you plot it??
#
#     - What else can you learn with this data?
#         - Try using the data in a new way and output your results to data/nyt_output.csv
#         - HINT: df.to_csv(file_name)

# %%
df.head()
# Out:
#    Age  Gender  Impressions  Clicks  Signed_In  impressions_squared  \
# 0   36       0            3       0          1                    9
# 1   73       1            3       0          1                    9
# 2   30       0            3       0          1                    9
# 3   49       1            3       0          1                    9
# 4   47       1           11       0          1                  121
#
#    clicks_per_impression
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0

# %%
df

# %%
df_nozeros.Gender.sum()
# Out:
# 168265

# %%
total_women = 0
total_men = 0
irrelevant = 0
dfno0_gender = df_nozeros.Gender
for item in dfno0_gender:
    if item == 1:
        total_women = total_women + 1
    elif item == 0:
        total_men = total_men + 1
    else:
        irrelevant = irrelevant + 1

# %%
total_women
# Out:
# 168265

# %%
total_men
# Out:
# 290175

# %%
irrelevant
# Out:
# 0

# %%
df_nozeros.Age
# Out:
# 1         73
# 2         30
# 3         49
# 4         47
# 5         47
# 6          0
# 7         46
# 8         16
# 9         52
# 10         0
# 11        21
# 12         0
# 13        57
# 14        31
# 15         0
# 16        40
# 17        31
# 18        38
# 19         0
# 20        59
# 21        61
# 22        48
# 23        29
# 24         0
# 25        19
# 26        19
# 27        48
# 28        48
# 29        21
# 30        23
#           ..
# 458411    55
# 458412    68
# 458413     0
# 458414    21
# 458415    35
# 458416    26
# 458417    41
# 458418    58
# 458419    46
# 458420    45
# 458421    46
# 458422    47
# 458423    22
# 458424    21
# 458425    40
# 458426    49
# 458427    43
# 458428    40
# 458429    49
# 458430     0
# 458431    21
# 458432    30
# 458433    21
# 458434    61
# 458435    51
# 458436     0
# 458437     0
# 458438    72
# 458439     0
# 458440     0
# Name: Age, dtype: int64

# %%
average_age
# Out:
# 80
